# %%
import numpy as np
import pickle
from pathlib import Path
from hmmlearn import hmm
import json
from collections import defaultdict

# %%
data_dir = Path("spectrogram_data")
train_features = np.load(data_dir / "train_features.npy")  # Shape: (12848, 20)
train_names = pickle.load(open(data_dir / "train_names.pkl", 'rb'))
pca_model = pickle.load(open(data_dir / "pca_model.pkl", 'rb'))

# %%
n_hidden_states = 10
n_iter = 200
    
# Create and train HMM
model = hmm.GaussianHMM(
    n_components=n_hidden_states,
    covariance_type='diag',
    n_iter=n_iter,
    random_state=42,
    verbose=1
    )

# %%
model.fit(train_features)
# Out:
#          1 -243322.12219034             +nan
#          2 -168062.80940556  +75259.31278478
#          3 -154335.56640638  +13727.24299918
#          4 -148973.11222520   +5362.45418118
#          5 -144079.47250965   +4893.63971555
#          6 -140635.08454669   +3444.38796296
#          7 -137815.06049212   +2820.02405457
#          8 -133097.60559286   +4717.45489925
#          9 -129465.69655503   +3631.90903784
#         10 -128332.79908732   +1132.89746770
#         11 -128040.14206663    +292.65702069
#         12 -127845.75304612    +194.38902051
#         13 -127652.60579707    +193.14724906
#         14 -127292.60314736    +360.00264971
#         15 -126759.88642157    +532.71672579
#         16 -125759.67053957   +1000.21588200
#         17 -125727.83916854     +31.83137103
#         18 -125688.27626705     +39.56290150
#         19 -125638.64094412     +49.63532293
#         20 -125592.50357828     +46.13736584
#         21 -125526.32293679     +66.18064150
#         22 -125488.14620700     +38.17672979
#         23 -125466.07270145     +22.07350555
#         24 -125443.49740272     +22.57529874
#         25 -125389.71825283     +53.77914989
#         26 -125362.60980926     +27.10844357
#         27 -125338.15356311     +24.45624616
#         28 -125309.35301658     +28.80054652
#         29 -125295.19611609     +14.15690049
#         30 -125291.48933201      +3.70678408
#         31 -125289.91668849      +1.57264352
#         32 -125289.04253871      +0.87414977
#         33 -125288.48709725      +0.55544146
#         34 -125288.09643471      +0.39066254
#         35 -125287.80081584      +0.29561888
#         36 -125287.56645019      +0.23436565
#         37 -125287.37572845      +0.19072174
#         38 -125287.21861523      +0.15711322
#         39 -125287.08873403      +0.12988120
#         40 -125286.98154012      +0.10719391
#         41 -125286.89346554      +0.08807458
#         42 -125286.82152518      +0.07194036
#         43 -125286.76314152      +0.05838366
#         44 -125286.71606762      +0.04707390
#         45 -125286.67835063      +0.03771699
#         46 -125286.64830867      +0.03004196
#         47 -125286.62450999      +0.02379868
#         48 -125286.60575055      +0.01875944
#         49 -125286.59102930      +0.01472125
#         50 -125286.57952238      +0.01150692
#         51 -125286.57054488      +0.00897751
# GaussianHMM(n_components=10, n_iter=200, random_state=42, verbose=1)
